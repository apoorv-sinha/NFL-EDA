# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
Def = pd.read_csv('DefA.csv', engine='python')

# %%
Def.head()
# Out:
#         Player_Name  Sacks  Tackles  Fumbles_Forced Position      Team
# 0      Robert Quinn   18.0       49               4       DE     Bears
# 1         Nick Bosa   15.5       52               4       DE    Niners
# 2      Myles Garret   16.0       51               1       DE    Browns
# 3           TJ Watt   22.5       64               5       LB  Steelers
# 4  Trey Hendrickson   14.0       34               3       DE   Bengals

# %%
sns.boxplot(x = 'Tackles', y = 'Position', data = Def)
# Out:
# <AxesSubplot:xlabel='Tackles', ylabel='Position'>

# %%
sns.boxplot(x = 'Fumbles_Forced', y = 'Position', data = Def)
# Out:
# <AxesSubplot:xlabel='Fumbles_Forced', ylabel='Position'>

# %%
sns.boxplot(x = 'Sacks', y = 'Position', data = Def)
# Out:
# <AxesSubplot:xlabel='Sacks', ylabel='Position'>

# %%
sns.violinplot(x = 'Fumbles_Forced', y = 'Position', data = Def)
# Out:
# <AxesSubplot:xlabel='Fumbles_Forced', ylabel='Position'>

# %%
sns.violinplot(x = 'Sacks', y = 'Position', data = Def)
# Out:
# <AxesSubplot:xlabel='Sacks', ylabel='Position'>

# %%
sns.violinplot(x = 'Tackles', y = 'Position', data = Def)
# Out:
# <AxesSubplot:xlabel='Tackles', ylabel='Position'>
